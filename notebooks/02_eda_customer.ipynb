# %% [markdown]
# # 🕵️‍♀️ Análisis Exploratorio Preliminar (EDA): Clientes
#
# ## 📋 Descripción
# Primer contacto con el archivo de datos demográficos (`customer-details.xlsx`). Usamos herramientas de exploración automática para entender la estructura y la suciedad de los datos antes de procesarlos.
#
# ## 📂 Datos
# * **Fuente:** `../data/customer-details.xlsx` (Datos Crudos / Raw).
# * **Herramienta:** Librería personalizada `src.sp_eda`.
#
# ## ⚙️ Pasos del Análisis
# 1.  **Carga de Datos:** Lectura del archivo Excel original.
# 2.  **Auditoría Automática (`se.eda_preliminar`):**
#     * Revisión de dimensiones (filas/columnas).
#     * Identificación de columnas clave (como el ID).
#     * Detección de valores nulos o inconsistentes en variables como 'Income' o fechas.
#     * Análisis rápido de frecuencias en variables categóricas.

# %%
# -------------------------------------------------------------------------
# CARGA DEL ARCHIVO CUSTOMERS-DETAILS.XLSX
# -------------------------------------------------------------------------
# tratamiento de dados
import pandas as pd
pd.set_option('display.max_columns', None)
#-------------------------------

# exploracion de archivos
import sys
sys.path.append('../')
#-------------------------------

#funciones personalizadas
from src import sp_eda as se
#-------------------------------

# %%
# carga de datos
df_clientes = pd.read_excel("../data/customer-details.xlsx")

# %%
# exploracion preliminar
se.eda_preliminar(df_clientes)
# Out:
# --- 1. MUESTRA ALEATORIA ---
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 15574       15574   87083        0         0  2012-04-21                 27
# 14156       14156   58989        1         2  2012-09-14                  6
# 1696         1696  130249        1         2  2012-01-01                  5
# 10222       10222  157379        0         1  2012-01-03                  5
# 5912         5912   63107        1         2  2012-10-13                 23
#
#                                          ID
# 15574  87b09df7-924c-4c15-a2ef-3974cc8e4dec
# 14156  3a6bdb79-53e7-4389-b754-68f8bb5764cc
# 1696   c9f749c6-3437-4b20-a91b-999ca982e87f
# 10222  ba2a99fb-df52-4f9a-a783-67c80290643b
# 5912   c6c2b06f-ad97-4c57-a803-78c56f44d4f3
# --- 2. DIMENSIONES ---
# Filas: 20115 | Columnas: 7
#
# --- 3. INFO GENERAL ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20115 entries, 0 to 20114
# Data columns (total 7 columns):
# ...
