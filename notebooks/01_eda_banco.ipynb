# %% [markdown]
# # 🕵️‍♀️ Análisis Exploratorio Preliminar (EDA): Banco
#
# ## 📋 Descripción
# Este notebook es el **punto de partida**. Su objetivo es realizar una radiografía inicial del archivo crudo de marketing (`bank-additional.csv`) para detectar problemas de calidad antes de intentar limpiarlos.
#
# ## 📂 Datos
# * **Fuente:** `../data/bank-additional.csv` (Datos Crudos / Raw).
# * **Herramienta:** Librería personalizada `src.sp_eda`.
#
# ## ⚙️ Pasos del Análisis
# 1.  **Carga de Datos:** Lectura del CSV original.
# 2.  **Auditoría Automática (`se.eda_preliminar`):**
#     * Visualización de muestra aleatoria.
#     * Detección de tipos de datos incorrectos (ej: números guardados como texto).
#     * Conteo de valores nulos y duplicados.
#     * Revisión de valores únicos en columnas de texto (para ver si hay 'unknown' o formatos raros).

# %%
# -------------------------------------------------------------------------
# CARGA DEL ARCHIVO BANK-ADDITIONAL.CSV
# -------------------------------------------------------------------------
# tratamiento de dados
import pandas as pd
pd.set_option('display.max_columns', None)
#-------------------------------

# exploracion de archivos
import sys
sys.path.append('../')
#-------------------------------

#funciones personalizadas
from src import sp_eda as se
#-------------------------------

# %%
# carga de datos
df = pd.read_csv("../data/bank-additional.csv")

# %%
# exploracion preliminar
se.eda_preliminar(df)
# Out:
# --- 1. MUESTRA ALEATORIA ---
#        Unnamed: 0   age            job   marital          education  default  \
# 27791       27935  36.0  self-employed   MARRIED  university.degree      0.0
# 23839       23936  29.0     technician    SINGLE  university.degree      0.0
# 31935       32079  48.0         admin.   MARRIED           basic.9y      0.0
# 39158       39325   NaN        student    SINGLE                NaN      0.0
# 6943         7040  29.0   entrepreneur  DIVORCED           basic.9y      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 27791      1.0   0.0   cellular       101         1    999         0
# 23839      0.0   0.0  telephone        36         1    999         0
# 31935      0.0   0.0   cellular       253         3    999         0
# 39158      0.0   1.0   cellular       248         1      3         4
# 6943       1.0   0.0  telephone       596         1    999         0
#
# ...
