# %%
import pandas as pd
import sys
sys.path.append('../')
from src import sp_vis as sv

# Carga de datos finales
df = pd.read_csv('../data/procesados/datos_finales_analisis.csv')

print("✅ Datos cargados para el Informe Ejecutivo.")
print(f"   - Total de Clientes Analizados: {df.shape[0]}")
print(f"   - Variables Disponibles: {df.shape[1]}")
# Out:
# ✅ Datos cargados para el Informe Ejecutivo.
#    - Total de Clientes Analizados: 20018
#    - Variables Disponibles: 28

# %% [markdown]
# # 📑 Informe Ejecutivo: Optimización de Campañas de Marketing Bancario

# %% [markdown]
# ## 1. Resumen Ejecutivo

# %% [markdown]
# El presente proyecto ha analizado más de **20.000 interacciones** con clientes para determinar las causas de la baja conversión en la venta de depósitos a plazo fijo.
#
# **El Diagnóstico:**
# La campaña actual es **ineficiente**. Se están dedicando recursos masivos a contactar perfiles con bajísima probabilidad de compra, ignorando patrones clave de comportamiento.
#
# **Las Cifras Clave:**
# * **Tasa de Conversión Actual:** `4.6%` (Crítica).
# * **Desperdicio de Recursos:** El `95.4%` de las llamadas resultan en fracaso.
# * **Oportunidad:** Existen nichos demográficos (Jóvenes/Jubilados) que duplican o triplican la eficiencia media.

# %% [markdown]
# ## 2. Hallazgos Estratégicos (Insights)

# %% [markdown]
# Tras un análisis exhaustivo de los datos, hemos detectado 4 pilares fundamentales que explican el rendimiento actual:
#
# ### 📉 A. El Desafío del 4.6% (Objetivo)
# Estamos ante un escenario de **"Aguja en el Pajar"**. La tasa de éxito es extremadamente baja. Esto implica que disparar a todo lo que se mueve es una estrategia perdedora. Se requiere urgentemente un modelo predictivo para filtrar el "No" antes de descolgar el teléfono.
#
# ### 👥 B. La Paradoja del Perfil (Cliente)
# * **Estrategia Actual:** El banco centra sus esfuerzos masivos en perfiles **`blue-collar` (obreros)** y **`admin.`**, que tienen tasas de respuesta muy pobres.
# * **El Nicho de Oro:** Los **Estudiantes** y **Jubilados** muestran una predisposición mucho más alta a la compra.
#     * *Dato:* Aunque se les llama poco, cuando se hace, la probabilidad de éxito se dispara.
#
# ### 💰 C. La Irrelevancia del Dinero (Economía)
# Sorprendentemente, los datos demuestran que **el nivel de ingresos NO influye** en la decisión de compra.
# * La mediana de ingresos es idéntica entre compradores y no compradores.
# * Este producto no entiende de clases sociales; es transversal.
#
# ### 🤖 D. La "Estrategia Robot" (Estacionalidad)
# El análisis temporal revela una gestión plana y monótona:
# * Se realizan aprox. **1.600 llamadas/mes** de forma constante, sin importar la época del año.
# * No hay adaptación estacional. El banco opera en "piloto automático", obteniendo resultados planos y bajos todo el año.

# %% [markdown]
# ## 3. Recomendaciones y Hoja de Ruta

# %% [markdown]
# Basándonos en la evidencia de los datos, proponemos el siguiente plan de acción para transformar la campaña:
#
# ### ✅ Acción 1: Pivotar el Target (Smart Targeting)
# Dejar de saturar a los perfiles `blue-collar` y redirigir el presupuesto de marketing hacia los segmentos de **Estudiantes (<25 años)** y **Seniors (>60 años)**. Aunque el volumen total de llamadas baje, la tasa de conversión neta subirá.
#
# ### ✅ Acción 2: Implementar IA Predictiva
# Dado el desbalanceo del 95% de negativas, es imperativo desplegar un modelo de **Machine Learning (Clasificación)**.
# * *Objetivo:* Asignar una probabilidad de compra a cada cliente **antes** de llamar.
# * *Impacto:* Si filtramos el 30% de los clientes con peor "score", podríamos ahorrar miles de horas de teleoperadores sin perder apenas ventas.
#
# ### ✅ Acción 3: Romper la Estacionalidad Plana
# Abandonar la estrategia de llamadas constantes. Realizar pruebas A/B concentrando esfuerzos en meses específicos (ej: inicio de curso escolar para estudiantes, pagas extra para jubilados) en lugar de mantener un ritmo plano de 1.600 llamadas/mes que ha demostrado ser ineficaz.
#
# ---
# **Firmado:** *David Morales Mendez* 🚀
